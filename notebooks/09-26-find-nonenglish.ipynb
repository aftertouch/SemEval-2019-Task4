# %% [markdown]
# Load data and preprocessing module

# %%
import pandas as pd

import sys
sys.path.append('../src')

# %load_ext autoreload
# %autoreload 1

from datatasks.custom_features import detect_language
# %aimport datatasks.custom_features
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATA_PATH = '../data/'
DATA_INTERIM_PATH = DATA_PATH + 'interim/'

train = pd.read_csv(DATA_INTERIM_PATH + 'train.csv')
val = pd.read_csv(DATA_INTERIM_PATH + 'val.csv')

# %%
train['language'] = train['article_text'].apply(detect_language)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d9048a5ee067> in <module>()
# ----> 1 train['language'] = train['article_text'].apply(detect_language)
#
# ~/anaconda3/envs/SemEval2019-4/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# ~/VCU/Fall2018/CMSC516/Project/src/datatasks/custom_features.py in detect_language(text)
#     111     """
#     112
# --> 113     ratios = _calculate_languages_ratios(text)
#     114
#     115     most_rated_language = max(ratios, key=ratios.get)
#
# ...

# %%
train['language'].value_counts()

# %%
non_english = train[~(train['language'] == 'english')]
non_english.reset_index(inplace=True, drop=True)
non_english.to_csv(DATA_PATH + 'processed/' + 'nonenglish_train.csv', index=False)

# %%
train.to_csv(DATA_PATH + 'interim/' + 'train.csv', index=False)

# %%
non_english['language'].value_counts()
# Out:
# spanish        5918
# french          569
# azerbaijani     541
# danish          122
# hungarian       119
# dutch            33
# romanian         33
# italian          27
# arabic           12
# indonesian        4
# german            3
# portuguese        2
# Name: language, dtype: int64

# %%
non_english['hyperpartisan'].value_counts()
# Out:
# False    6673
# True      710
# Name: hyperpartisan, dtype: int64

# %%
non_english[(non_english['hyperpartisan'] == True) & (non_english['title'].str.contains('National Liberty Federation') == False)]
# Out:
#              id published-at  \
# 4413       9326   2018-01-31
# 5089      10725   2018-01-31
# 5090      10726   2018-01-31
# 11477     24023   2018-01-31
# 46335     89764   2017-06-09
# 46848     90594   2018-07-15
# 51100     97394   2017-07-12
# 60388    112240   2018-01-31
# 64554    118870   2018-01-31
# 67987    125997   2018-01-31
# 68595    127249   2018-01-31
# 74728    139061   2018-01-31
# 86548    161809   2017-10-12
# 91252    171619   2018-01-31
# 91388    171874   2017-08-10
# 92350    173887   2012-12-18
# 94975    179300   2018-01-31
# 99582    189039   2018-01-31
# 101790   193620   2015-12-29
# 107540   205447   2018-01-31
# 115033   220989   2000-06-15
# 121423   234388   2018-01-31
# 121424   234390   2018-07-15
# 123909   239467   2018-07-15
# 124944   241611   2018-01-31
# 125186   242080   2018-01-31
# 131654   255468   2018-01-31
# 147104   287991   2017-10-12
# 154298   302977   2018-01-31
# 154526   303472   2018-01-31
# ...         ...          ...
# ...

# %%
val['language'] = val['article_text'].apply(detect_language)

# %%
non_english = val[~(val['language'] == 'english')]
non_english.reset_index(inplace=True, drop=True)
non_english.to_csv(DATA_PATH + 'processed/' + 'nonenglish_val.csv', index=False)

# %%
val.to_csv(DATA_PATH + 'interim/' + 'val.csv', index=False)

# %%
train.drop('published-at', axis=1)
# Out:
#              id                                              title  \
# 0             1  After DeVos Announced Plans To Reexamine Title...
# 1             2  University To Award Trayvon Martin With Posthu...
# 2             8  Texas State University suspends Greek life aft...
# 3             9  Red Sox waste Rodriguez outing in 1-0 loss to ...
# 4            10                          Eve and the New Jerusalem
# 5            12  Jewish Organization's Huge Day Of Unity On Tue...
# 6            15  BREAKING: Trump Reaches Agreement To Keep 1,00...
# 7            16             Winning numbers drawn in ?2 By 2? game
# 8            20  ANALYSIS: Does gay debate mirror church disput...
# 9            21         Slideshow: Salvaging Burned Books in Egypt
# 10           25  How schools in Brazil are teaching kids to eat...
# 11           27  Massive venomous snake found under New Orleans...
# 12           28  Meet The Anti-Refugee ?Hate? Group That Just L...
# ...

# %%
train.head()
# Out:
#    id published-at                                              title  \
# 0   1   2017-09-10  After DeVos Announced Plans To Reexamine Title...
# 1   2   2017-05-05  University To Award Trayvon Martin With Posthu...
# 2   8   2017-11-15  Texas State University suspends Greek life aft...
# 3   9   2015-06-10  Red Sox waste Rodriguez outing in 1-0 loss to ...
# 4  10          NaN                          Eve and the New Jerusalem
#
#                                         article_text  \
# 0  When explaining her decision to reevaluate Tit...
# 1  A Florida university will honor Trayvon Martin...
# 2  Nov. 15 (UPI) ? Texas State University has sus...
# 3  BALTIMORE (AP) ? On a night in which Boston di...
# 4  Imaginings of a utopian, or utopian socialist,...
#
#                                       external_links internal_links  \
# 0  {'https://www.nbcnews.com/news/us-news/betsy-d...             {}
# 1  {'https://www.facebook.com/FLMemorialUniv/': '...             {}
# ...
