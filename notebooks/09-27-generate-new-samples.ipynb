# %%
import pandas as pd

import sys
sys.path.append('../src/data')

# %load_ext autoreload
# %autoreload 1

import sample_data
# %aimport sample_data

# %%
DATA_PATH = '../data/'
DATA_INTERIM_PATH = DATA_PATH + 'interim/'
train = pd.read_csv(DATA_INTERIM_PATH + 'train.csv')
val = pd.read_csv(DATA_INTERIM_PATH + 'val.csv')

# %%
train.head()
# Out:
#    id published-at                                              title  \
# 0   1   2017-09-10  After DeVos Announced Plans To Reexamine Title...
# 1   2   2017-05-05  University To Award Trayvon Martin With Posthu...
# 2   8   2017-11-15  Texas State University suspends Greek life aft...
# 3   9   2015-06-10  Red Sox waste Rodriguez outing in 1-0 loss to ...
# 4  10          NaN                          Eve and the New Jerusalem
#
#    hyperpartisan          bias  \
# 0           True         right
# 1           True         right
# 2          False  right-center
# 3          False         least
# 4           True          left
#
#                                                  url labeled-by  \
# 0  https://dailywire.com/news/20858/after-devos-a...  publisher
# 1  https://dailywire.com/news/16103/university-aw...  publisher
# 2  https://newsline.com/texas-state-university-su...  publisher
# 3  https://apnews.com/795c45f6db904f8eb85d72cee61...  publisher
# ...

# %%
train = train[train['language'] == 'english']
val = val[val['language'] == 'english']

# %%
train.shape
# Out:
# (792617, 9)

# %%
val.shape
# Out:
# (199897, 9)

# %%
samples = sample_data.sample_preprocess_data(train, 2, 10000, 'train', save=True)

# %%
train.head()
# Out:
#    id published-at                                              title  \
# 0   1   2017-09-10  After DeVos Announced Plans To Reexamine Title...
# 1   2   2017-05-05  University To Award Trayvon Martin With Posthu...
# 2   8   2017-11-15  Texas State University suspends Greek life aft...
# 3   9   2015-06-10  Red Sox waste Rodriguez outing in 1-0 loss to ...
# 4  10          NaN                          Eve and the New Jerusalem
#
#    hyperpartisan          bias  \
# 0           True         right
# 1           True         right
# 2          False  right-center
# 3          False         least
# 4           True          left
#
#                                                  url labeled-by  \
# 0  https://dailywire.com/news/20858/after-devos-a...  publisher
# 1  https://dailywire.com/news/16103/university-aw...  publisher
# 2  https://newsline.com/texas-state-university-su...  publisher
# 3  https://apnews.com/795c45f6db904f8eb85d72cee61...  publisher
# ...

# %%
train[train['url'].str.contains('beast') & (train['hyperpartisan'] == True)]
# Out:
#              id published-at  \
# 25           59   2018-07-14
# 44          103   2018-07-14
# 67          147   2018-07-14
# 68          150   2018-07-14
# 90          196   2018-07-14
# 169         342   2018-07-14
# 212         434   2018-07-14
# 310         630   2018-07-14
# 356         735   2018-07-14
# 368         757   2018-07-14
# 399         821   2018-07-14
# 418         860   2018-07-14
# 425         879   2018-07-14
# 505        1050   2018-07-14
# 564        1176   2018-07-14
# 592        1231   2018-07-14
# 612        1277   2018-07-14
# 629        1312   2018-07-14
# 699        1461   2018-07-14
# 787        1665   2018-07-14
# 816        1723   2018-07-14
# 927        1992   2018-07-14
# 976        2084   2018-07-14
# 988        2102   2018-07-14
# 996        2122   2018-07-14
# 1051       2239   2018-07-14
# 1060       2258   2018-07-14
# 1180       2501   2018-07-14
# 1226       2611   2018-07-14
# 1242       2659   2018-07-14
# ...         ...          ...
# ...

# %%
train[train['article_text'].str.contains('parry')]['hyperpartisan'].value_counts()
# Out:
# True     81
# False    48
# Name: hyperpartisan, dtype: int64
