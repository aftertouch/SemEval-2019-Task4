# %% [markdown]
# ## SemEval 2019 Task 4 - Testing sampling script
#
# Jonathan Miller and Negar Adyaniyazdi, VCU, CMSC516, Fall 2018

# %%
import sys
sys.path.append('../src/data')

# %load_ext autoreload
# %autoreload 1

import sample_data
# %aimport sample_data

import pandas as pd

# %%
DATA_PATH = '../data/'
DATA_INTERIM_PATH = DATA_PATH + 'interim/'
train = pd.read_csv(DATA_INTERIM_PATH + 'train.csv')

# %%
samples = sample_data.sample_preprocess_data(train, 1, 10000, 'train', save=True)

# %%
samples[0].head()
# Out:
#     index      id published-at  \
# 0  158171  310969   2008-12-10
# 1  480078  945112          NaN
# 2  258275  519393   2017-12-31
# 3   20237   42462   2017-03-09
# 4  354111  736303   2017-11-23
#
#                                                title  hyperpartisan  \
# 0                      Sweden's ailing auto industry          False
# 1  Kidnapped Canadian Mining Executive is Now a P...           True
# 2  Separate car wrecks claim father and son withi...          False
# 3  A GOP Congressman Just Spent 6 Minutes Defendi...           True
# 4  No more ?fighting ISIS?? US to stay in Syria t...          False
#
#            bias                                                url labeled-by  \
# 0   left-center  https://pri.org/stories/2008-12-10/swedens-ail...  publisher
# 1          left  http://occupy.com/article/kidnapped-canadian-m...  publisher
# 2         least  https://apnews.com/64fbe3af704a402aa1f1ceb071a...  publisher
# ...
